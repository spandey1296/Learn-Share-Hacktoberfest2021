# %% [markdown]
# ![q3.jpg](data:image/jpeg;base64,...)

# %%
// import required libraries
#include<stdio.h>
#include<string.h>
// initializing the main function
int main(){
    // defining the strings
    char str1[20],str2[20],str3[20],str4[20];
    printf("\n Enter one weather condition (rainy/sunny/cloudy/foggy): ");
    scanf("%s", str1);  
    printf("\n Enter the month(January/february/March...: ");
    scanf("%s", str2); 
    printf("\n Enter the Day(Monday/Tuesday/Wednesday....: ");
    scanf("%s", str3); 
    printf("\n Enter one weather condition (rainy/sunny/cloudy/foggy): ");
    scanf("%s", str4); 
    
   printf("\n****************************************************");
   // variale to store the compared result 
   int value=strcmp(str1,str4);  
   if(value==0){
    printf("\nStrings %s and %s are same",str1,str4);
    }else  
    printf("\n Strings %s and %s are not same",str1,str4);  
    printf("\n****************************************************");
   // variable to store the length of string 
   int length = strlen(str3);
   printf("\n Length of the string3  = %d\n", length);
   printf("\n****************************************************");
   printf("\n The original String str2 is  %s",str2);
   printf("\n****************************************************");
   // strcpy method to copy the strings
   strcpy(str2, "mockingbird");
   printf("\n The modified String str2 is  %s",str2);
   printf("\n****************************************************");
   printf("\n The original String str1 is  %s",str1);
   printf("\n The original String str2 is  %s",str2);
   printf("\n****************************************************");
   // concatenating the strings using strcat
   strcat(str1,str2);  
   printf("\n The concatenated string str1 is : %s",str1);
   printf("\n The concatenated string str2 is : %s",str2);
   printf("\n****************************************************");
   
}
