# %% [markdown]
# ![val2.jpg](data:image/jpeg;base64,...)

# %%
#include<stdio.h>
int gcd_num(int temp1,int temp2);
int main(){
    int num1,num2,gcd,x;
    printf("Enter number 1 and number 2\n");
    scanf("%d%d",&num1,&num2);
    
    gcd=gcd_num(num1,num2);
    
    printf("gcd is %d\n",gcd);
}
    
int gcd_num(int temp1,int temp2){
    if(temp2!=0){
    gcd_num(temp2,temp1%temp2);
    }else{
    return(temp1);
    }
}
