# %% [markdown]
# ![q1.png](data:image/png;base64,...)

# %%
Solution:

Program:

#include <stdio.h>

void ReverseInt(int *no){     // function to reverse the number
    int number = *no;        //declare a number to assign the pointer value
    int rem;                 // rem to calculate the remainder
    *no = 0;
    // while loop to revere the number
    while(number!=0){
        rem = number%10;
        *no = *no * 10 + rem;
        number = number/10;
    }
}


// declare the main function
int main()
{
    int N;
    int *num = &N;
    
    // User input
    printf("Enter a Number : ");
    scanf("%d",&N);
    
    // Passing the number to the ReverseInt function
    ReverseInt(num);
    // Printing the reverse of the number.
    printf("After Reversing the number : %d",N);
    return 0;
}
