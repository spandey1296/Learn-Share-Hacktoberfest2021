# %% [markdown]
# ![q.jpg](data:image/jpeg;base64,...)

# %%
#include<iostream>
using namespace std; 
int main( ) 
{  
    double arr[4][3] = {
        { 5, 1.1, 6.2},
        { -3,0 ,0 },
        { 2, 1, 9.1 },
        { 0, 8,7 }
        } ;
         
    int i,j;
     
    cout<<"The array A is: \n";
    for(i=0;i<4;i++)
    {
        for(j=0;j<3;j++)
        {
            cout<<"\t"<<arr[i][j];
        }
        cout<<endl;
    }
}
