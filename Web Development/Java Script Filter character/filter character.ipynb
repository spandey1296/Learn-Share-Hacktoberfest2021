# %% [markdown]
# ![q4.jpg](data:image/jpeg;base64,...)
#
#
#
# ![q5.jpg](data:image/jpeg;base64,...)

# %%
<!DOCTYPE html>
<html>

<head>
    <title></title>
    <script type="text/javascript">

    // Declare the array of strings
    var words = ['hello', 'sunshine', 'apple', 'orange', 'pineapple'];

    var wordsWithA = words.filter(word => word.includes('a'));



    // Uncomment the following code if you want the code without filter function

    // var wordsLength = words.length;
    // for (var i = 0; i < wordsLength; i++) {
    //     var findme = "a";
    //     if (words[i].indexOf(findme) > -1) {
    //         alert(" The character 'a' is present is words " + words[i]);
    //         console.log(words[i]);
    //     } else {
    //         alert(" The character 'a' is not present is words " + words[i]);
    //     }

    // }
    </script>
</head>
<body>
</body>

</html>
