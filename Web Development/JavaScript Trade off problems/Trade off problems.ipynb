# %% [markdown]
# ![q6.jpg](data:image/jpeg;base64,...)

# %%
All the problems are implemented in trade off acceleration average running time.

 

 

1. Finding the sum of integers

Program:

<!DOCTYPE html>
<html>

<head>
    <title></title>
    <script type="text/javascript">

    //declaring the function iSigma
    function iSigma(number){
        let sum = 0;

    // looping from i = 1 to number
    // in each iteration, i is increased by 1
    for (let i = 1; i <= number; i++) {
        sum += i;
    }

    // Printing the result on console
    console.log('The sum of integers :', sum);

    }

    
    </script>
</head>

<body>
</body>

</html>

 

Program Pic

<!DOCTYPE html>
<html>
<head>
<title></title>
<script type=text/javascript>||
//declaring the function isigma
function iSig

 

Output

Elements
Console
Sources
Netwc
top
o
Filter
> iSigma(1)
The sum of integers : 1
< undefined
> iSigma(2)
The sum of integers :

 

 

2. Factorial

 

Program:

 

<!DOCTYPE html>
<html>

<head>
    <title></title>
    <script type="text/javascript">

   // declaration of factorial number
    function Factorial(num) {
        if (num < 0)
            return -1;
        else if (num == 0)
            return 1;
        else {
            // recurvie function - trade off algorithm
            return (num * Factorial(num - 1));
        }
    }
    </script>
</head>

<body>
</body>

</html>

 

Program Pic



 

Output



 

3. Fibanocci Series:

Program:

<!DOCTYPE html>
<html>

<head>
    <title></title>
    <script type="text/javascript">


    // declaring the function 
    function iFib(num) {

   return num < 1 ? 0
        : num <= 2 ? 1
        : iFib(num - 1) + iFib(num - 2);  // trade off condition
}
    </script>
</head>

<body>
</body>

</html>

 

Program pic

<!DOCTYPE html>
<html>
<head>
<title></title>
<script type=text/javascript>
function iFib(num) {
return num < 1 ? 0
: num <

 

Output Pic:

Console
Sources
Filter
a Elements
Do top o
> iFib(0)
< 0
> iFib(1)
< 1
> iFib(2)
1
> iFib(3)
< 2
1

 

4. Tribanocci Series

Program:

 

<!DOCTYPE html>
<html>

<head>
    <title></title>
    <script type="text/javascript">

// declare Trinonacci function
function Trinonacci(n)
{
    // base conditions
    if (n == 0 || n == 1 || n == 2)
        return 0;

    if (n == 3)
        return 1;
    else 
        // trade off algorithm
        return Trinonacci(n - 1) +
            Trinonacci(n - 2) +
            Trinonacci(n - 3);
}


</script>

</head>

<body>
</body>

</html>

 

 

Program Pic



 

Output Pic

Elements
Console
Sc
o
Filter
Do top
> Trinonacci(0)
> Trinonacci(3)
< 1
> Trinonacci(5)
< 2
> Trinonacci(7)
< 7
> Trinonacci(
