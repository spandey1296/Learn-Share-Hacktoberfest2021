# %% [markdown]
# ![q9.png](data:image/png;base64,...)

# %%
# importing the counter from collections
from collections import Counter
# defining the list of elements
A = [2,9,2,6,4,3,3,2]
# passing list into counter 
count = Counter(A)
#print("The elements repeated count: ",count)
#clecking for duplicate values
duplicate_values = list([x for x in count if d[x]>1])
#printing the duplicate values found
print("The duplicate values found: ",duplicate_values)
# Out:
# The duplicate values found:  [2, 3]
