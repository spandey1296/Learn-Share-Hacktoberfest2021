# %% [markdown]
# ![q8.png](data:image/png;base64,...)

# %%
def func(x,y):
  if(x<=1 or y<=1):
    return x
  if(x%2==0):
    return func(2*y-1,x/2)
  else:
    return func(x-1,y)

xValue = int(input("Enter x value: "))
yValue = int(input("Enter y value: "))
print(func(xValue,yValue))
# Out:
# Enter x value: 69
# Enter y value: 63
# 59.0
