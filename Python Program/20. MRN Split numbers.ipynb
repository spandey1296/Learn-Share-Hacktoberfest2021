# %% [markdown]
# ![q3.jfif](data:image/jpeg;base64,...)

# %%
# getting mrn value from user
mrn = input()
x = []
# getting the number 
array = [int(n) for n in input().split()]
# iterating over the list
for i in array:
      # slicing the mrn
      x.append(mrn[-i:])
      # spliting based on list value
      mrn = mrn.split(mrn[-i:])[0]
# joining the values
out = "-".join(x)
# displaying the result
print(out)
# Out:
# 8126595674
# 3 2 4 1
# 674-95-1265-8

# %%
8126595674
