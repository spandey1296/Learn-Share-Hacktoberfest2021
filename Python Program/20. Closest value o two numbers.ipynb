# %% [markdown]
# ![q2.png](data:image/png;base64,...)

# %%
# defining the function
def closest(target,v1,v2):
  # getting the closest value 
  takeClosest = lambda num,collection:min(collection,key=lambda x:abs(x-num))
  # returing the closest value 
  return takeClosest
# list to store values
userList = []
# getting the target value
target = float(input("Enter target: "))
# getting the first comparision value
v1 = float(input("Enter v1: "))
# getting the second comparision value
v2 = float(input("Enter v2: "))
# appending the values to the list
userList.append(v1)
userList.append(v2)
# calling the function
result = takeClosest(target,userList)
# displaying the result
print(f'Closest value to {target} is {result}')
# Out:
# Enter target: 5.2
# Enter v1: 3.4
# Enter v2: 9.8
# Closest value to 5.2 is 3.4
